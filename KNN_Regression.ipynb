# %% [markdown]
# <a href="https://colab.research.google.com/github/hvmt2003/K-NN-/blob/main/KNN_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv('/content/Salary_Data.csv')

# %%
dataset.head()
# Out:
#     Age  YearsExperience  Salary
# 0  21.0              1.1   39343
# 1  21.5              1.3   46205
# 2  21.7              1.5   37731
# 3  22.0              2.0   43525
# 4  22.2              2.2   39891

# %%
dataset.isnull().sum()
# Out:
# Age                0
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
x=dataset.iloc[:,:-1]
y=dataset.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=10)

# %%
from sklearn.neighbors import KNeighborsRegressor
knn=KNeighborsRegressor(n_neighbors=5)
knn.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
knn.score(x_test,y_test)
# Out:
# 0.9250089226590515

# %%
for i in range(1,30):
  knn1=KNeighborsRegressor(n_neighbors=i)
  knn1.fit(x_train,y_train)
  print('K=',i,"Accuracy:",knn1.score(x_test,y_test))
# Out:
# K= 1 Accuracy: 0.9339199493843671
# K= 2 Accuracy: 0.9517430412028514
# K= 3 Accuracy: 0.9700573991638958
# K= 4 Accuracy: 0.9480897380156007
# K= 5 Accuracy: 0.9250089226590515
# K= 6 Accuracy: 0.9068155347419189
# K= 7 Accuracy: 0.8927057099871489
# K= 8 Accuracy: 0.8858847599420269
# K= 9 Accuracy: 0.8703522392353051
# K= 10 Accuracy: 0.8681599894527807
# K= 11 Accuracy: 0.8508088718602405
# K= 12 Accuracy: 0.8369239125939176
# K= 13 Accuracy: 0.8016290822308065
# K= 14 Accuracy: 0.7333575524131839
# K= 15 Accuracy: 0.6845435252351197
# K= 16 Accuracy: 0.5980039714377298
# K= 17 Accuracy: 0.487374180753422
# K= 18 Accuracy: 0.3799956199007174
# K= 19 Accuracy: 0.2705226341135697
# K= 20 Accuracy: 0.15248930309645325
# K= 21 Accuracy: 0.04761715717774606
# K= 22 Accuracy: -0.09865056887391987
# K= 23 Accuracy: -0.26937933316338847
# K= 24 Accuracy: -0.4418339813099159
# ---------------------------------------------------------------------------
# ...
